# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/exchange_rate.csv')
df
# Out:
#             date   Ex_rate
# 0     1990-01-01  0.785500
# 1     1990-01-02  0.781800
# 2     1990-01-03  0.786700
# 3     1990-01-04  0.786000
# 4     1990-01-05  0.784900
# ...          ...       ...
# 7583  2010-10-06  0.718494
# 7584  2010-10-07  0.721839
# 7585  2010-10-08  0.723197
# 7586  2010-10-09  0.720825
# 7587  2010-10-10  0.720825
#
# [7588 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Ex_rate'].plot(kind='hist', bins=20, title='Ex_rate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['date_ordinal'].plot(kind='hist', bins=20, title='date_ordinal')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7588 entries, 0 to 7587
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     7588 non-null   object
#  1   Ex_rate  7588 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 118.7+ KB

# %%
df.describe()
# Out:
#            Ex_rate
# count  7588.000000
# mean      0.776974
# std       0.136620
# min       0.483297
# 25%       0.701422
# 50%       0.761377
# 75%       0.873477
# max       1.102536

# %%
df.shape
# Out:
# (7588, 2)

# %%
df.columns.tolist()
# Out:
# ['date', 'Ex_rate']

# %%
df.columns
# Out:
# Index(['date', 'Ex_rate'], dtype='object')

# %%
df.isnull()
# Out:
#        date  Ex_rate
# 0     False    False
# 1     False    False
# 2     False    False
# 3     False    False
# 4     False    False
# ...     ...      ...
# 7583  False    False
# 7584  False    False
# 7585  False    False
# 7586  False    False
# 7587  False    False
#
# [7588 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# date       0
# Ex_rate    0
# dtype: int64

# %%
#Initial Exploration
df.head()
# Out:
#          date  Ex_rate
# 0  1990-01-01   0.7855
# 1  1990-01-02   0.7818
# 2  1990-01-03   0.7867
# 3  1990-01-04   0.7860
# 4  1990-01-05   0.7849

# %%
df.hist(figsize=(10, 10), color='blue', grid=False, bins=20, xlabelsize=8,
        ylabelsize=8, rwidth=0.9, alpha=0.7, layout=(4, 4),
        sharex=False, sharey=False)

# Set xticks and yticks using plt.xticks() and plt.yticks()
plt.xticks(range(0, 25000, 5000))
plt.yticks(range(0, 25000, 5000))

plt.show()

# %%
# Plot the exchange rates
# Assuming the Date column is named 'date' and Exchange Rate is named 'Ex_rate'
plt.plot(df['date'], df['Ex_rate'])  # Changed column names to 'date' and 'Ex_rate'
plt.xlabel('Date')
plt.ylabel('Exchange Rate')
plt.title('Exchange Rates Over Time')
plt.show()

# %%
plt.plot(df['date'], df['Ex_rate'])
plt.xlabel('Date')
plt.ylabel('Exchange Rate')
plt.title('Exchange Rates Over Time')
plt.show()

# %%
#boxplot
plt.boxplot(df['Ex_rate'])
plt.xlabel('Exchange Rate')
plt.title('Box Plot of Exchange Rates')
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#          Ex_rate
# Ex_rate      1.0

# %%
df.hist(figsize=(10,10))
plt.show()

# %%
df['date'].value_counts()
# Out:
# date
# 1990-01-01    1
# 2003-11-03    1
# 2003-11-15    1
# 2003-11-14    1
# 2003-11-13    1
#              ..
# 1996-11-30    1
# 1996-11-29    1
# 1996-11-28    1
# 1996-11-27    1
# 2010-10-10    1
# Name: count, Length: 7588, dtype: int64

# %%
df['Ex_rate'].value_counts()
# Out:
# Ex_rate
# 0.740500    11
# 0.776500    10
# 0.784000    10
# 0.740000     9
# 0.765000     9
#             ..
# 0.801000     1
# 0.792800     1
# 0.759100     1
# 0.760950     1
# 0.728371     1
# Name: count, Length: 5330, dtype: int64

# %%
#distplot
sns.distplot(df['Ex_rate'])
# Out:
# <Axes: xlabel='Ex_rate', ylabel='Density'>

# %%
sns.pairplot(df)

# %%
sns.violinplot(df['Ex_rate'])
# Out:
# <Axes: ylabel='Ex_rate'>

# %%
sns.violinplot(df['date'])
# Out:
# <Axes: ylabel='date'>

# %%
sns.pointplot(x='date', y='Ex_rate', data=df)
# Out:
# <Axes: xlabel='date', ylabel='Ex_rate'>

# %%
sns.kdeplot(df['Ex_rate'])
# Out:
# <Axes: xlabel='Ex_rate', ylabel='Density'>

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
sns.kdeplot(df['date'])
# Out:
# <Axes: xlabel='date', ylabel='Density'>

# %%
sns.scatterplot(x='date', y='Ex_rate', data=df)
# Out:
# <Axes: xlabel='date', ylabel='Ex_rate'>

# %%
sns.hls_palette().as_hex()
# Out:
# ['#db5f57', '#d3db57', '#57db5f', '#57d3db', '#5f57db', '#db57d3']

# %%
sns.boxenplot(df['Ex_rate'])
# Out:
# <Axes: ylabel='Ex_rate'>

# %%
sns.boxenplot(df['date'])
# Out:
# <Axes: ylabel='date'>

# %%
sns.catplot(x='date', y='Ex_rate', data=df)

# %%
sns.jointplot(x='date', y='Ex_rate', data=df)

# %%
sns.barplot(x='date', y='Ex_rate', data=df)
# Out:
# <Axes: xlabel='date', ylabel='Ex_rate'>

# %%
sns.clustermap(df.corr())

# %%
sns.lineplot(x='date', y='Ex_rate', data=df)
# Out:
# <Axes: xlabel='date', ylabel='Ex_rate'>

# %%
df['date_ordinal'] = pd.to_numeric(df['date'])

# %%
sns.lmplot(x='date_ordinal', y='Ex_rate', data=df)
sns.despine()

# %%
#pie
plt.pie(df['Ex_rate'], labels=df['date'], autopct='%1.1f%%')
plt.title('Exchange Rates by Date')
plt.show()

# %%
#3. Data Preprocessing
#Handling Missing Values
df.fillna(df.mean(), inplace=True)

# %%
# Check for anomalies (e.g., values that are too high or too low)
anomalies = df[(df['Ex_rate'] < df['Ex_rate'].quantile(0.05)) | (df['Ex_rate'] > df['Ex_rate'].quantile(0.95))]
print(anomalies)
# Out:
#            date   Ex_rate         date_ordinal
# 2637 1997-03-22  0.538331   858988800000000000
# 2638 1997-03-23  0.538715   859075200000000000
# 2644 1997-03-29  0.542217   859593600000000000
# 2647 1997-04-01  0.535854   859852800000000000
# 2648 1997-04-02  0.537293   859939200000000000
# ...         ...       ...                  ...
# 6239 2007-01-31  1.050001  1170201600000000000
# 6240 2007-02-01  1.050900  1170288000000000000
# 6241 2007-02-02  1.037646  1170374400000000000
# 6242 2007-02-03  1.039301  1170460800000000000
# 6620 2008-02-16  1.077760  1203120000000000000
#
# [759 rows x 3 columns]

# %%
# This is a simple example; you may want to use more sophisticated methods
df.drop(anomalies.index, inplace=True)

# %%
df=df[(df['Ex_rate']>0) & (df['Ex_rate']<2)]
df['Ex_rate'].mean()
# Out:
# 0.7758735901303266

# %%
df['Ex_rate'].median()
# Out:
# 0.7614

# %%
df['Ex_rate'].mode()
# Out:
# 0    0.7405
# Name: Ex_rate, dtype: float64

# %%
df['Ex_rate'].std()
# Out:
# 0.11257865428932798

# %%
df['Ex_rate'].var()
# Out:
# 0.012673953401596025

# %%
df['Ex_rate'].skew()
# Out:
# 0.3742607585301931

# %%
df['Ex_rate'].kurt()
# Out:
# -0.2442721712371454

# %%
####Part 2: Model Building - ARIMA

# %%
#1. Parameter Selection for ARIMA
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import acf, pacf

# %%
#Use ACF and PACF plots to determine the parameters.
# Plot ACF and PACF
plt.figure(figsize=(12, 6))
plot_acf(df['Ex_rate'], lags=40, title='Autocorrelation Function (ACF)')
plot_pacf(df['Ex_rate'], lags=40, title='Partial Autocorrelation Function (PACF)')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plot_acf(df['date'], lags=40, title='Autocorrelation Function (ACF)')
plot_pacf(df['date'], lags=40, title='Partial Autocorrelation Function (PACF)')
plt.show()

# %%
#2. Model Fitting
#Fit the ARIMA model using the selected parameters (p, d, q).
model = ARIMA(df['Ex_rate'], order=(1, 1, 1))
model_fit = model.fit()
model_fit.summary()
model_fit.plot_diagnostics(figsize=(15, 12))
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                Ex_rate   No. Observations:                 6829
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               25790.207
# Date:                Fri, 18 Oct 2024   AIC                         -51574.414
# Time:                        17:39:01   BIC                         -51553.927
# Sample:                             0   HQIC                        -51567.346
#                                - 6829
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5836      0.058     -9.987      0.000      -0.698      -0.469
# ma.L1          0.5240      0.060      8.687      0.000       0.406       0.642
# sigma2      3.067e-05   1.71e-07    178.998      0.000    3.03e-05     3.1e-05
# ...

# %%
#4. Forecasting
#Perform out-of-sample forecasting.
forecast_steps = 10
forecast = model_fit.forecast(steps=forecast_steps)
forecast
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 6829    0.720754
# 6830    0.720795
# 6831    0.720771
# 6832    0.720785
# 6833    0.720777
# 6834    0.720782
# 6835    0.720779
# 6836    0.720781
# 6837    0.720780
# 6838    0.720780
# Name: predicted_mean, dtype: float64

# %%
#plot
forecast=model_fit.forecast(steps=forecast_steps)
plt.figure(figsize=(12, 6))
plt.plot(df['Ex_rate'], label='Actual')
plt.plot(forecast, label='Forecast', color='red', linestyle='--', marker='o', markersize=8, markerfacecolor='red', markeredgecolor='black', markeredgewidth=1, alpha=0.7)
plt.xlabel('Date')
plt.ylabel('Exchange Rate')
plt.title('ARIMA Model Forecast')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
#Part 3: Model Building - Exponential Smoothing
#model selection 1
#Choose an appropriate Exponential Smoothing model.
## Fit Holt-Winters model (example)
from statsmodels.tsa.holtwinters import ExponentialSmoothing
model = ExponentialSmoothing(df['Ex_rate'], trend='add', seasonal='add', seasonal_periods=12)
model_fit = model.fit()
model_fit.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:                  Ex_rate   No. Observations:                 6829
# Model:             ExponentialSmoothing   SSE                              0.209
# Optimized:                         True   AIC                         -70936.985
# Trend:                         Additive   BIC                         -70827.722
# Seasonal:                      Additive   AICC                        -70936.885
# Seasonal Periods:                    12   Date:                 Fri, 18 Oct 2024
# Box-Cox:                          False   Time:                         17:45:52
# ...

# %%
#2. Parameter Optimization
#Use AIC for parameter optimization.
print(f'AIC: {model_fit.aic}')
print(f'BIC: {model_fit.bic}')
print(f'SSE: {model_fit.sse}')
# Out:
# AIC: -70936.98542055211
# BIC: -70827.72248408874
# SSE: 0.20943080288864252

# %%
#3. Model Fitting and Forecasting
#Fit the model and visualize the forecasts.
# Forecasting with Holt-Winters
forecast_steps = 10
forecast = model_fit.forecast(steps=forecast_steps)
plt.figure(figsize=(12, 6))
plt.plot(df['Ex_rate'], label='Actual')
plt.plot(forecast, label='Forecast', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Exchange Rate')
plt.title('Holt-Winters Forecast')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
#Part 4: Evaluation and Comparison
#Calculate MAE, RMSE, and MAPE.
from sklearn.metrics import mean_absolute_error, mean_squared_error
actual_values = df['Ex_rate'].tail(forecast_steps)  # Get the last 'forecast_steps' values
print("Actual Values:")
print(actual_values)  # Print the actual values
# Out:
# Actual Values:
# 7578    0.717618
# 7579    0.719114
# 7580    0.719114
# 7581    0.719735
# 7582    0.718701
# 7583    0.718494
# 7584    0.721839
# 7585    0.723197
# 7586    0.720825
# 7587    0.720825
# Name: Ex_rate, dtype: float64

# %%
mae = mean_absolute_error(actual_values, forecast)
rmse = mean_squared_error(actual_values, forecast, squared=False)
mape = np.mean(np.abs((actual_values - forecast) / actual_values)) * 100
print("Forecast Values:")
print(forecast)  # Print the forecast values
print("Actual Values:")
print(actual_values)  # Print the actual values
print(f'MAE: {mae}')
print(f'RMSE: {rmse}')
print(f'MAPE: {mape}')
print(f'SSE: {model_fit.sse}')
# Out:
# Forecast Values:
# 6829    0.721294
# 6830    0.721258
# 6831    0.721240
# 6832    0.721021
# 6833    0.721178
# 6834    0.720955
# 6835    0.721133
# 6836    0.721189
# 6837    0.721212
# 6838    0.720967
# dtype: float64
# Actual Values:
# 7578    0.717618
# 7579    0.719114
# 7580    0.719114
# 7581    0.719735
# 7582    0.718701
# 7583    0.718494
# 7584    0.721839
# 7585    0.723197
# 7586    0.720825
# 7587    0.720825
# Name: Ex_rate, dtype: float64
# MAE: 0.001741371370566669
# RMSE: 0.002029271551989804
# MAPE: nan
# SSE: 0.20943080288864252

# %%
#3d plot
import plotly.express as px
df = px.data.gapminder()
fig = px.scatter(df, x="gdpPercap", y="lifeExp", size="pop", color="continent",
                 hover_name="country", log_x=True, size_max=60)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df=px.data.gapminder()
fig=px.scatter(df,x='gdpPercap',y='lifeExp',size='pop',color='continent',hover_name='country',log_x=True,size_max=60,animation_frame='year',animation_group='country')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.groupby('continent').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()

# %%
df.groupby('continent').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.show()
